# %% [markdown]
# # LCEL을 활용한 다중 프롬프트 & LLM 체인 연결 예시
# ## 1. LCEL의 정의와 배경
#
# - **LCEL**은 **LangChain Expression Language**의 약자입니다.
# - LangChain 0.1.17 이후 등장한 **최신 체인(Chain) 구축 방식**으로,
#   프롬프트, LLM, 파서, 커스텀 함수 등 **모든 컴포넌트를 파이프라인(연산자 연결) 형태로 선언적 조합**할 수 있게 해줍니다.
# - **목적:**
#   - 더 직관적이고, 유연하며, 유지보수/확장에 강한 LLM 워크플로우를
#     "마치 Unix 파이프라인이나 함수 합성"처럼 만들 수 있도록 설계
#
# ---
#
# ## 2. 기존 방식 vs LCEL 방식
#
# - **전통적 LangChain (예: LLMChain)**
#     - 객체 선언 및 체인 클래스 위주의 구조
#     - 다단계 체인을 만들 때 번거로움이 있고, 코드 중복이 많아질 수 있음
#     - 절차적으로 여러 단계를 나누어 처리해야 하며, 코드 가독성이 낮아질 수 있음
#
# - **LCEL 방식 (`|` 파이프 연산자)**
#     - 연산자(`|`) 기반의 선언적 파이프라인 구조
#     - 단계 추가, 중간 변환, 조건 분기 등이 매우 쉬움
#     - 한 줄의 직관적 코드로 복잡한 중첩 구조와 변환, 확장 처리가 자유롭게 가능
# ---
#
# ## 3. 핵심 문법 및 패턴
#
# ### 3.1. **기본 문법**
#
# ```python
# chain = prompt | llm | StrOutputParser()
# ```python
# chain = (
#     first_prompt
#     | llm
#     | StrOutputParser()
#     | {"title": lambda x: x}
#     | second_prompt
#     | llm
#     | StrOutputParser()
# )

# %% [markdown]
# ## 1. 구조 및 목적
#
# - **목적:**
#   하나의 파이프라인(chain)에서 여러 단계의 프롬프트-LLM 처리를 순차적으로 연결하여
#   입력값 → 1차 생성 → 중간 변환 → 2차 프롬프트 → 최종 생성
#   **다단계 생성 과정을 자동화**합니다.
#
# ---
#
# ## 2. 각 단계별 역할
#
# 1. **first_prompt**
#     - 첫 번째 프롬프트 템플릿
#     - 예: `'입력값'에 대한 간단한 요약을 작성해줘.`
#
# 2. **llm**
#     - LLM(Gemini, OpenAI 등) 모델 호출
#     - first_prompt에서 생성된 프롬프트에 따라 1차 응답 생성
#
# 3. **StrOutputParser()**
#     - LLM 응답 객체(AIMessage 등)를 파이썬 문자열(str)로 변환
#
# 4. **{"title": lambda x: x}**
#     - 딕셔너리 기반 필드 변환 단계
#     - 이전 결과(문자열)를 `title`이라는 이름의 필드로 매핑
#     - (입력값 형태를 `{ "title": 이전 결과 }`로 변환)
#     - 두 번째 프롬프트에서 `{title}` 변수로 활용 가능
#
# 5. **second_prompt**
#     - 두 번째 프롬프트 템플릿
#     - 예: `'{title}'에 어울리는 해시태그를 추천해줘.`
#
# 6. **llm**
#     - LLM으로 2차 생성
#     - 두 번째 프롬프트에 따라 최종 결과 생성
#
# 7. **StrOutputParser()**
#     - 두 번째 LLM 응답도 파이썬 문자열로 변환
#
# ---
#
# ## 3. 전체 흐름 예시
#
# - 입력값
#   → first_prompt
#   → LLM(1차 생성)
#   → 문자열 변환
#   → `{"title": ...}` 구조로 변환
#   → second_prompt
#   → LLM(2차 생성)
#   → 최종 문자열
#
# ---
#
# ## 4. 실무적 활용
#
# - **다단계 생성 파이프라인:**
#   예: 초안 생성 → 요약 → 해시태그 추천, 질문 생성 → 답변 생성 → 평가 등
# - 입력값 변환/가공 및 중간 데이터 재활용이 쉬움
# - 각 단계의 결과를 명확하게 관리·확장 가능
#
# ---
#
# ## 5. 요약
#
# - **LCEL(파이프라인 패턴)을 이용하면**
#   여러 프롬프트와 LLM을 직관적으로 연결하여
#   복잡한 생성형 워크플로우도 한 줄 코드로 간결하게 구현할 수 있습니다.

# %%
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
import os

# 환경변수 로드 및 API 키 확인
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError(".env 파일에 GOOGLE_API_KEY를 반드시 입력하세요.")

# Gemini LLM 객체 생성
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",    # 또는 "gemini-pro" 등 사용 가능
    google_api_key=api_key,
    temperature=0.7
)

# 첫 번째 체인: 아이디어 생성
first_prompt = PromptTemplate.from_template(
    "'{topic}'에 대한 블로그 글 제목을 하나 제안해주세요."
)

# 두 번째 체인: 개요 작성
second_prompt = PromptTemplate.from_template(
    "다음 제목의 블로그 글 개요를 작성해주세요: {title}"
)

# LCEL을 사용한 체인 연결
chain = (
    first_prompt
    | llm
    | StrOutputParser()
    | {"title": lambda x: x}
    | second_prompt
    | llm
    | StrOutputParser()
)

# 실행
result = chain.invoke({"topic": "인공지능과 미래"})
print(result)
# Out:
# ## 블로그 글 개요: 'AI, 미래를 엿보다: 기회와 도전'
#
# **타겟 독자:** 인공지능에 관심 있는 일반 대중, 미래 사회 변화에 대한 이해를 넓히고 싶은 사람들
#
# **목표:** 인공지능의 발전이 가져올 미래의 기회와 도전을 균형 있게 제시하고, 독자들이 미래를 긍정적으로 준비할 수 있도록 돕는다.
#
# **I. 서론 (독자의 흥미를 유발하고 글의 방향 제시)**
#
# *   A. 인공지능의 현재 발전 상황 간략하게 소개 (예: 챗GPT, 자율주행차 등 구체적인 예시 언급)
# *   B. 인공지능이 우리 삶에 미치는 영향력에 대한 질문 던지기 (예: 일자리, 교육, 문화 등)
# *   C. 'AI, 미래를 엿보다: 기회와 도전'이라는 제목 소개 및 글의 목적 명확히 제시
#
# **II. 본론 1: 인공지능이 가져올 미래의 기회**
#
# *   A. 경제적 기회:
#     *   1. 새로운 산업 및 일자리 창출 (예: AI 개발자, 데이터 과학자, AI 윤리 전문가 등)
#     *   2. 생산성 향상 및 자동화로 인한 효율 증대
#     *   3. 개인 맞춤형 서비스 및 제품 개발 가능성 증가
# *   B. 사회적 기회:
#     *   1. 헬스케어 분야 혁신 (예: 질병 예측, 맞춤형 치료, 로봇 수술 등)
#     *   2. 교육 분야 혁신 (예: 개인 맞춤형 학습, AI 튜터 등)
#     *   3. 환경 문제 해결 기여 (예: 기후 변화 예측, 에너지 효율 향상 등)
# *   C. 삶의 질 향상:
#     *   1. 편리하고 스마트한 생활 환경 구축 (예: 스마트 홈, 스마트 시티 등)
#     *   2. 여가 시간 증대 및 개인의 창의성 발휘 기회 증가
#
# **III. 본론 2: 인공지능이 가져올 미래의 도전**
#
# *   A. 일자리 감소 및 불평등 심화:
#     *   1. 자동화로 인한 특정 직업군의 일자리 감소
#     *   2. AI 기술 격차로 인한 사회적 불평등 심화 가능성
#     *   3. 새로운 일자리에 대한 적응 능력 부족 문제
# *   B. 윤리적 문제:
#     *   1. AI 알고리즘의 편향성 문제 (예: 성별, 인종 차별)
#     *   2. 개인 정보 보호 및 사생활 침해 우려
#     *   3. AI의 자율성 및 책임 소재 불분명
# *   C. 사회적 혼란:
#     *   1. AI가 만든 가짜 정보 (deepfake) 확산으로 인한 혼란
#     *   2. AI 의존도 증가로 인한 인간의 능력 저하 우려
#     *   3. AI와의 공존에 대한 사회적 합의 부족
#
# **IV. 결론 (미래를 위한 준비 자세 강조)**
#
# *   A. 인공지능의 기회와 도전을 균형 있게 요약
# *   B. 미래 사회에 필요한 역량 강조 (예: 비판적 사고, 창의성, 협업 능력)
# *   C. 인공지능을 긍정적으로 활용하기 위한 노력 촉구 (예: AI 윤리 교육, 사회적 논의 참여)
# *   D. 독자들에게 미래를 준비하는 긍정적인 메시지 전달
#
# **추가 고려 사항:**
#
# *   각 본론에서 구체적인 사례 및 통계 자료를 활용하여 내용의 신뢰성 확보
# *   이미지, 동영상 등 시각 자료를 활용하여 독자의 이해도 향상
# *   독자들의 참여를 유도하기 위한 질문 던지기 또는 댓글 기능 활용
# *   SEO를 위해 관련 키워드를 적절히 배치 (예: 인공지능, 미래, 일자리, 윤리, 헬스케어 등)
#
# 이 개요를 바탕으로 독자들에게 유익하고 흥미로운 블로그 글을 작성할 수 있을 것입니다. 성공적인 글쓰기를 응원합니다!
